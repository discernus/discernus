# %% [markdown]
# # Exp 01: Core Replication - Tamaki & Fuks (2019)
# **Framework:** democratic_tension_axis_model_brazil_2018
# **Generated:** 2025-06-30T18:58:34.378955
# **Job ID:** corpus_job_20250630_185833
#
# ## Real Analysis Results
# ✅ **22 analyses completed**
# 🤖 **2 models compared:** gpt-4o-mini, claude-3-haiku-20240307
# 📊 **Mean discourse intensity:** 0.157
# 📈 **Model agreement:** 0.886 (higher = more similar)
#
# ### Framework Description
# A computational framework for analyzing Brazilian political discourse based on the theoretical
# foundation established by Tamaki & Fuks (2019). This framework operationalizes the competitive
# dynamics between populist and pluralist democratic orientations, as well as between patriotic
# civic attachment and nationalist identity-based appeals in the context of Brazilian political discourse.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image, display
import base64

# Analysis results (pre-loaded)
experiment_data = {
  "models_dataframe": {
    "model": {
      "0": "gpt-4o-mini",
      "1": "claude-3-haiku-20240307"
    },
    "centroid_x": {
      "0": -0.019176117031719144,
      "1": 0.003636363636363636
    },
    "centroid_y": {
      "0": 0.22005606547263418,
      "1": 0.09286713286713288
    },
    "num_analyses": {
      "0": 11,
      "1": 11
    },
    "magnitude": {
      "0": 0.2208900075053429,
      "1": 0.0929382994650622
    },
    "angle_degrees": {
      "0": 94.98028569850048,
      "1": 87.7576361214175
    }
  },
  "statistical_analysis": {
    "centroid_distances": [
      0.2208900075053429,
      0.0929382994650622
    ],
    "mean_magnitude": 0.15691415348520255,
    "std_magnitude": 0.09047552041968378,
    "coordinate_spread": {
      "x_std": 0.026044652134172938,
      "y_std": 0.10151162489431095,
      "overall_variance": 0.012234461363146027
    },
    "inter_model_distances": [
      {
        "model_1": "gpt-4o-mini",
        "model_2": "claude-3-haiku-20240307",
        "distance": 0.12921855072534438
      }
    ],
    "mean_inter_model_distance": 0.12921855072534438
  },
  "framework_insights": {
    "framework_name": "democratic_tension_axis_model_brazil_2018",
    "framework_description": "A computational framework for analyzing Brazilian political discourse based on the theoretical \nfoundation established by Tamaki & Fuks (2019). This framework operationalizes the competitive \ndynamics between populist and pluralist democratic orientations, as well as between patriotic \ncivic attachment and nationalist identity-based appeals in the context of Brazilian political discourse.\n",
    "theoretical_dimensions": 2,
    "axis_names": [
      "Populism_Pluralism",
      "Patriotism_Nationalism"
    ],
    "model_spread": {
      "x_range": 0.02281248066808278,
      "y_range": 0.1271889326055013,
      "most_extreme_model": "gpt-4o-mini",
      "most_central_model": "claude-3-haiku-20240307"
    }
  },
  "visualization_path": "...",
  "experiment_metadata": {
    "job_id": "corpus_job_20250630_185833",
    "framework_name": "democratic_tension_axis_model_brazil_2018",
    "total_analyses": 22,
    "models_analyzed": [
      "gpt-4o-mini",
      "claude-3-haiku-20240307"
    ]
  }
}

# Convert to DataFrame for easy manipulation
models_df = pd.DataFrame(experiment_data['models_dataframe'])
stats = experiment_data['statistical_analysis']
insights = experiment_data['framework_insights']

print('📊 Analysis loaded successfully!')
print('🎯 Framework: democratic_tension_axis_model_brazil_2018')
print('🤖 Models analyzed: 2')
print('📈 Total analyses: 22')
print('✅ Ready for interactive exploration!')
# Out:
# 📊 Analysis loaded successfully!
# 🎯 Framework: democratic_tension_axis_model_brazil_2018
# 🤖 Models analyzed: 2
# 📈 Total analyses: 22
# ✅ Ready for interactive exploration!

# %%
# Model comparison results
print('📊 Model Comparison Results:')
display(models_df)

print(f'\n📈 Statistical Summary:')
print(f'   Mean discourse intensity: 0.157')
print(f'   Standard deviation: 0.090')
if 'mean_inter_model_distance' in stats:
    print(f'   Mean inter-model distance: 0.129')
# Out:
# <div><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>centroid_x</th>
#       <th>centroid_y</th>
#       <th>num_analyses</th>
#       <th>magnitude</th>
#       <th>angle_degrees</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>gpt-4o-mini</td>
#       <td>-0.019176</td>
#       <td>0.220056</td>
#       <td>11</td>
#       <td>0.220890</td>
#       <td>94.980286</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>claude-3-haiku-20240307</td>
#       <td>0.003636</td>
#       <td>0.092867</td>
#       <td>11</td>
#       <td>0.092938</td>
#       <td>87.757636</td>
#     </tr>
#   </tbody>
# </table></div>

# %%
# Display the coordinate visualization
from IPython.display import Image
import base64

# Decode and display the visualization
image_data = '...'
display(Image(data=base64.b64decode(image_data)))

# %%
# Interactive analysis of results
print('🎯 Key Insights:')
print(f'• Most extreme positioning: gpt-4o-mini')
print(f'• Most central positioning: claude-3-haiku-20240307')
print(f'• Coordinate spread: X=0.023, Y=0.127')

print('\n💡 Research Implications:')
print('• Model differences suggest distinct analytical perspectives')
print('• Coordinate positioning reflects theoretical framework structure')
print('• Ready for academic validation and publication!')

# Additional analysis can be added here
# Users can modify and extend this notebook as needed
# Out:
# 🎯 Key Insights:
# • Most extreme positioning: gpt-4o-mini
# • Most central positioning: claude-3-haiku-20240307
# • Coordinate spread: X=0.023, Y=0.127
#
# 💡 Research Implications:
# • Model differences suggest distinct analytical perspectives
# • Coordinate positioning reflects theoretical framework structure
# • Ready for academic validation and publication!
